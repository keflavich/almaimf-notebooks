# %%
# %matplotlib inline

# %%
import numpy as np
from astropy import units as u

# %%
import pylab as pl
pl.rcParams['figure.figsize'] = (16,8)

# %%
import sys
sys.path.append('/lustre/naasc/users/aginsbur/repos/reduction/reduction/')
import imp, diagnostic_images
imp.reload(diagnostic_images)
from diagnostic_images import load_images, show
from spectral_cube import SpectralCube
import warnings
import spectral_cube
warnings.filterwarnings(action='ignore', category=spectral_cube.utils.StokesWarning)
warnings.filterwarnings(action='ignore', category=spectral_cube.utils.BeamWarning)

# %%
import os
os.chdir("/lustre/lard/projects/ALMA_IMF/2017.1.01355.L/imaging_results")

# %%
ls -lhrtd W51-E_B3_uid___*_continuum_merged_7M_*.image.tt0
# Out:
# drwxr-xr-x 4 aginsbur observer 4.0K Jul 13 14:19 W51-E_B3_uid___A001_X1296_X109_continuum_merged_7M_robust0_dirty.image.tt0/
# drwxr-xr-x 4 aginsbur observer 4.0K Jul 13 14:24 W51-E_B3_uid___A001_X1296_X109_continuum_merged_7M_robust2_dirty.image.tt0/
# drwxr-xr-x 4 aginsbur observer 4.0K Jul 13 14:28 W51-E_B3_uid___A001_X1296_X109_continuum_merged_7M_robust-2_dirty.image.tt0/

# %%
imgs_dirty_b3, cubes_dirty_b3 = load_images('W51-E_B3_uid___A001_X1296_X109_continuum_merged_7M_robust0_dirty')

# %%
imgs_before_b3, cubes_before_b3 = load_images('W51-E_B3_uid___A001_X1296_X109_continuum_merged_7M_robust0')

# %%
imgs_after_b3, cubes_after_b3 = load_images('W51-E_B3_uid___A001_X1296_X109_continuum_merged_7M_robust0_selfcal1')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-29-6c2e933d198d> in <module>
# ----> 1 imgs_after_b3, cubes_after_b3 = load_images('W51-E_B3_uid___A001_X1296_X109_continuum_merged_7M_robust0_selfcal1')
#
# /lustre/naasc/users/aginsbur/repos/reduction/reduction/diagnostic_images.py in load_images(basename, crop)
#      13     for imn in imnames:
#      14         if not os.path.exists(f'{basename}.{imn}.tt0'):
# ---> 15             raise IOError(f"File {basename}.{imn}.tt0 does not exist")
#      16
#      17     cubes = {imn: SpectralCube.read(f'{basename}.{imn}.tt0', format='casa_image')
#
# OSError: File W51-E_B3_uid___A001_X1296_X109_continuum_merged_7M_robust0_selfcal1.image.tt0 does not exist

# %%
show(imgs_dirty_b3, vmin=-0.001, vmax=1.0)

# %%
show(imgs_before_b3, vmin=-0.001, vmax=1)

# %%
show(imgs_after_b3, vmin=-0.001, vmax=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-96bcb3e4d17b> in <module>
# ----> 1 show(imgs_after_b3, vmin=-0.001, vmax=1)
#
# NameError: name 'imgs_after_b3' is not defined
