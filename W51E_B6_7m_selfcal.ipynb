# %%
# %matplotlib inline

# %%
import numpy as np
from astropy import units as u

# %%
import pylab as pl
pl.rcParams['figure.figsize'] = (16,8)

# %%
import sys
sys.path.append('/lustre/naasc/users/aginsbur/repos/reduction/reduction/')
import imp, diagnostic_images
imp.reload(diagnostic_images)
from diagnostic_images import load_images, show
from spectral_cube import SpectralCube
import warnings
import spectral_cube
warnings.filterwarnings(action='ignore', category=spectral_cube.utils.StokesWarning)
warnings.filterwarnings(action='ignore', category=spectral_cube.utils.BeamWarning)

# %%
import os
os.chdir("/lustre/lard/projects/ALMA_IMF/2017.1.01355.L/imaging_results")

# %%
ls -lhrtd W51-E_B6_uid___*_continuum_merged_7M_*.image.tt0
# Out:
# drwxr-xr-x 4 aginsbur observer 4.0K Jul 12 23:31 W51-E_B6_uid___A001_X1296_X217_continuum_merged_7M_robust0_dirty.image.tt0/
# drwxr-xr-x 4 aginsbur observer 4.0K Jul 12 23:53 W51-E_B6_uid___A001_X1296_X217_continuum_merged_7M_robust2_dirty.image.tt0/
# drwxr-xr-x 4 aginsbur observer 4.0K Jul 13 00:14 W51-E_B6_uid___A001_X1296_X217_continuum_merged_7M_robust-2_dirty.image.tt0/
# drwxr-xr-x 4 aginsbur observer 4.0K Jul 13 16:37 W51-E_B6_uid___A001_X1296_X217_continuum_merged_7M_robust0.image.tt0/

# %%
imgs_dirty_b6, cubes_dirty_b6 = load_images('W51-E_B6_uid___A001_X1296_X217_continuum_merged_7M_robust0_dirty')
# Out:
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.spectral_cube]
# WARNING: BeamWarning: No beam information found in CASA image. [spectral_cube.io.casa_image]
# WARNING: StokesWarning: Cube is a Stokes cube, returning spectral cube for I component [spectral_cube.spectral_cube]

# %%
imgs_before_b6, cubes_before_b6 = load_images('W51-E_B6_uid___A001_X1296_X217_continuum_merged_7M_robust0')

# %%
imgs_after_b6, cubes_after_b6 = load_images('W51-E_B6_uid___A001_X1296_X217_continuum_merged_7M_robust0_selfcal1')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-23-7c8fb04eeb27> in <module>
# ----> 1 imgs_after_b6, cubes_after_b6 = load_images('W51-E_B6_uid___A001_X1296_X217_continuum_merged_7M_robust0_selfcal1')
#
# /lustre/naasc/users/aginsbur/repos/reduction/reduction/diagnostic_images.py in load_images(basename, crop)
#      13     for imn in imnames:
#      14         if not os.path.exists(f'{basename}.{imn}.tt0'):
# ---> 15             raise IOError(f"File {basename}.{imn}.tt0 does not exist")
#      16
#      17     cubes = {imn: SpectralCube.read(f'{basename}.{imn}.tt0', format='casa_image')
#
# OSError: File W51-E_B6_uid___A001_X1296_X217_continuum_merged_7M_robust0_selfcal1.image.tt0 does not exist

# %%
show(imgs_dirty_b6, vmin=-0.001, vmax=3.0)

# %%
show(imgs_before_b6, vmin=-0.001, vmax=1)

# %%
imgs_before_b6rm2, cubes_before_b6rm2 = load_images('W51-E_B6_uid___A001_X1296_X217_continuum_merged_7M_robust-2')
show(imgs_before_b6rm2, vmin=-0.001, vmax=1)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-24-a20bc294bdaa> in <module>
# ----> 1 imgs_before_b6rm2, cubes_before_b6rm2 = load_images('W51-E_B6_uid___A001_X1296_X217_continuum_merged_7M_robust-2')
#       2 show(imgs_before_b6rm2, vmin=-0.001, vmax=1)
#
# /lustre/naasc/users/aginsbur/repos/reduction/reduction/diagnostic_images.py in load_images(basename, crop)
#      13     for imn in imnames:
#      14         if not os.path.exists(f'{basename}.{imn}.tt0'):
# ---> 15             raise IOError(f"File {basename}.{imn}.tt0 does not exist")
#      16
#      17     cubes = {imn: SpectralCube.read(f'{basename}.{imn}.tt0', format='casa_image')
#
# OSError: File W51-E_B6_uid___A001_X1296_X217_continuum_merged_7M_robust-2.image.tt0 does not exist
